# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from dotenv import load_dotenv

load_dotenv()
from langchain.agents import create_agent
from langchain_groq import ChatGroq

groq_model = ChatGroq(
    model="llama-3.3-70b-versatile"
)
agent = create_agent(
    model=groq_model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='49e6ac27-75b9-4330-90e8-2d7c1d5b5309'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'cwqepvzg2', 'function': {'arguments': '{"x":467}', 'name': 'square_root'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 243, 'total_tokens': 257, 'completion_time': 0.046142722, 'completion_tokens_details': None, 'prompt_time': 0.012340982, 'prompt_tokens_details': None, 'queue_time': 0.161755126, 'total_time': 0.058483704}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ebce3-0217-7221-9659-bc448643c793-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'cwqepvzg2', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 243, 'output_tokens': 14, 'total_tokens': 257}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='e5b67b0d-5005-465d-95fb-3abdfb015a9e', tool_call_id='cwqepvzg2'),
#  AIMessage(content='The square root of 467 is 21.61018278497431.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 274, 'total_tokens': 291, 'completion_time': 0.03309205, 'completion_tokens_details': None, 'prompt_time': 0.030845852, 'prompt_tokens_details': None, 'queue_time': 0.057138207, 'total_time': 0.063937902}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ebce3-0359-7373-b2e1-a596bbcbf231-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 274, 'output_tokens': 17, 'total_tokens': 291})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'cwqepvzg2', 'type': 'tool_call'}]
