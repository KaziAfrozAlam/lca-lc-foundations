# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# ========== RUN THIS FIRST EVERY TIME ==========
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install",
    "langchain-groq", "langgraph", "langchain-core",
    "langchain", "langchain-openai", "langchain-deepseek",
    "langchain-google-genai", "python-dotenv"], check=False)
# ================================================
# Out:
# CompletedProcess(args=['c:\\Users\\ramiz\\AppData\\Local\\Python\\pythoncore-3.14-64\\python.exe', '-m', 'pip', 'install', 'langchain-groq', 'langgraph', 'langchain-core', 'langchain', 'langchain-openai', 'langchain-deepseek', 'langchain-google-genai', 'python-dotenv'], returncode=0)

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain_groq import ChatGroq

groq_model = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain_groq import ChatGroq

groq_model = ChatGroq(model="llama-3.3-70b-versatile")
agent = create_agent(model=groq_model, tools=[])

question = HumanMessage(content="What's the capital of the moon?")
response = agent.invoke({"messages": [question]})
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital. The Moon is a natural satellite that orbits the Earth, and it does not have a government or permanent human settlements. As a result, it does not have a capital city.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=groq_model,
    tools=[],
    system_prompt=system_prompt
)

response = scifi_agent.invoke({"messages": [question]})

print(response['messages'][-1].content)  # [1] → [-1]
# Out:
# There is no capital city of the moon, as the moon is a natural satellite and does not have a government or permanent human settlement. However, let me create a fictional capital city for a hypothetical lunar nation.
#
# Introducing "Lunaria" - the capital city of the moon. Located in the southeastern region of the moon's near side, Lunaria is a self-sustaining, futuristic metropolis built into the cratered terrain. The city's architecture is a blend of sleek, modern design and innovative, adaptive technology that allows it to thrive in the moon's harsh environment.
#
# Lunaria's cityscape is characterized by:
#
# 1. **The Crystal Dome**: A massive, transparent dome that encloses the city, providing a stable atmosphere and protecting its inhabitants from the moon's extreme temperatures and radiation.
# 2. **The Lunar Spire**: A towering, crystalline structure that serves as the city's central hub, housing the government, major institutions, and cutting-edge research facilities.
# 3. **The Gravity Rings**: A series of concentric, rotating rings that generate artificial gravity, allowing the city's inhabitants to live and work in a comfortable, Earth-like environment.
# 4. **The Solar Sails**: A network of thin, photovoltaic membranes that harness the sun's energy, providing power to the city and its various systems.
# 5. **The Hydroponic Gardens**: A vast, underground network of hydroponic farms that cultivate a wide variety of crops, using advanced aeroponics and precision agriculture techniques to feed the city's population.
#
# Lunaria is a beacon of human innovation and cooperation, serving as a hub for interplanetary diplomacy, scientific research, and exploration. The city is home to a diverse population of scientists, engineers, artists, and entrepreneurs, all working together to build a brighter, more sustainable future for humanity.
#
# Welcome to Lunaria, the shining capital of the moon!

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=groq_model,
    tools=[],
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the moon is Lunaria City, also known as New Tranquility. It's a bustling metropolis with a mix of lunar natives, Earth expats, and intergalactic visitors. The city is built into the cratered surface, with towering domes and sleek, curved architecture that blends seamlessly into the moon's rugged landscape. Lunaria City is the hub of lunar politics, commerce, and innovation, and is home to the prestigious Lunar University and the Moon's governing body, the Lunar Council.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=groq_model,
    tools=[],
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaria
#
# Location: Southern crater of the Moon's near side, in the Shackleton crater
#
# Vibe: Futuristic Oasis
#
# Economy: The main industries in Lunaria are Helium-3 mining, Space Tourism, and Advanced Manufacturing, with a focus on producing cutting-edge spacecraft and lunar-based technologies.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=groq_model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunar Haven', location='The Moon', vibe='futuristic', economy='space-based')

# %%
response["structured_response"].name
# Out:
# 'Lunar Haven'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunar Haven is a city located at The Moon
