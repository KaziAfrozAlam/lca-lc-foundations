# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent
from langchain_groq import ChatGroq

groq_model = ChatGroq(model="llama-3.1-8b-instant") 
agent = create_agent(
    model=groq_model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='a8cdecf4-e276-4af1-ba1a-f2afdca7c39c'),
#               AIMessage(content="I don't have any information about your personal preferences or favourite colours. I'm a large language model, I don't have the ability to retain information about individual users or their preferences. Each time you interact with me, it's a new conversation and I don't have any prior knowledge about you. Would you like to share your favourite colour with me?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 41, 'total_tokens': 113, 'completion_time': 0.102151899, 'completion_tokens_details': None, 'prompt_time': 0.003154507, 'prompt_tokens_details': None, 'queue_time': 0.046476043, 'total_time': 0.105306406}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eca35-1434-7842-bae3-de13123e7628-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 72, 'total_tokens': 113})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
groq_model = ChatGroq(model="llama-3.3-70b-versatile")

agent = create_agent(
    model=groq_model, 
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# c:\Users\ramiz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pydantic\functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# c:\Users\ramiz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='1e62a37c-cb64-4764-89d4-27220ced6627'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'r9tpkzz1f', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 267, 'total_tokens': 278, 'completion_time': 0.044297498, 'completion_tokens_details': None, 'prompt_time': 0.013896404, 'prompt_tokens_details': None, 'queue_time': 0.162204466, 'total_time': 0.058193902}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eca37-efc6-74b0-a853-c1264d9e503b-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'r9tpkzz1f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 11, 'total_tokens': 278}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='00bffe43-dcc4-41db-bca5-f1143ddb1744', tool_call_id='r9tpkzz1f'),
#               AIMessage(content='Your favourite colour is blue.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.01790531, 'completion_tokens_details': None, 'prompt_time': 0.021631008, 'prompt_tokens_details': None, 'queue_time': 0.161768217, 'total_time': 0.039536318}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eca37-f118-7682-82ae-1c1995059a80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# c:\Users\ramiz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pydantic\functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# c:\Users\ramiz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='363af2da-b2fc-4bfb-8b09-172435cb730c'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '008k8jcw3', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.039078042, 'completion_tokens_details': None, 'prompt_time': 0.014417122, 'prompt_tokens_details': None, 'queue_time': 0.046169458, 'total_time': 0.053495164}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eca38-4fa0-7d33-81e5-ba0e29d0cf8e-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '008k8jcw3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='green', name='get_favourite_colour', id='dfb911b6-2379-4618-8ffa-c1d7f1e9eacb', tool_call_id='008k8jcw3'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.016932779, 'completion_tokens_details': None, 'prompt_time': 0.014636616, 'prompt_tokens_details': None, 'queue_time': 0.161741624, 'total_time': 0.031569395}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eca38-505a-7a10-8fcd-c6ad5b18d270-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}
